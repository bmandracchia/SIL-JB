# %% [markdown]
# # Ejercicios de Autoevaluación

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from utils.test_helpers import create_answer_selector, create_numeric_input_exercise, create_true_false_exercise

# %% [markdown]
# :::{figure} ./videos/Presentacion_APG.mp4
# Antes de empezar con los ejercicios, revisemos algunos de los errores más comunes.
# :::

# %% [markdown]
# ## Señales continuas y discretas

# %%
create_true_false_exercise(
    statement="Una señal continua se representa normalmente como x(t).",
    solution=True
)

create_true_false_exercise(
    statement="Una señal discreta se representa normalmente como x[n].",
    solution=True
)

create_true_false_exercise(
    statement="Una señal discreta está definida para valores enteros de la variable independiente.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal continua solo puede tomar valores positivos.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal discreta puede representarse mediante diagramas de tallos.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal periódica siempre tiene energía finita.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal continua se representa normalmente como x[n].",
    solution=False
)

create_true_false_exercise(
    statement="Una señal discreta solo está definida para valores enteros de la variable independiente.",
    solution=True
)

create_true_false_exercise(
    statement="El valor pico de una señal puede ser negativo.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal impar cumple x(-t) = x(t).",
    solution=False
)

create_true_false_exercise(
    statement="Una señal par cumple x(-t)=x(t).",
    solution=True
)

create_true_false_exercise(
    statement="Una señal puede representar información física.",
    solution=True
)

create_true_false_exercise(
    statement="Las señales discretas siempre tienen amplitud entera.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal sinusoidal continua puede ser periódica.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal constante es aperiódica.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal continua se representa normalmente como x(t).</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_70bec3e1e5d348ecac433e4e69b8ebfb" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_70bec3e1e5d348ecac433e4e69b8ebfb" value="false">
#                 Falso
#             </label>
#
#             <button id="button_70bec3e1e5d348ecac433e4e69b8ebfb" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_70bec3e1e5d348ecac433e4e69b8ebfb" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_70bec3e1e5d348ecac433e4e69b8ebfb").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_70bec3e1e5d348ecac433e4e69b8ebfb");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_70bec3e1e5d348ecac433e4e69b8ebfb");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal discreta se representa normalmente como x[n].</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d7a73b01b42348f786d976b2740f747f" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d7a73b01b42348f786d976b2740f747f" value="false">
#                 Falso
#             </label>
#
#             <button id="button_d7a73b01b42348f786d976b2740f747f" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_d7a73b01b42348f786d976b2740f747f" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d7a73b01b42348f786d976b2740f747f").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_d7a73b01b42348f786d976b2740f747f");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_d7a73b01b42348f786d976b2740f747f");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal discreta está definida para valores enteros de la variable independiente.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bf7aeb42fe69427aaa18ca70e8189ae6" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bf7aeb42fe69427aaa18ca70e8189ae6" value="false">
#                 Falso
#             </label>
#
#             <button id="button_bf7aeb42fe69427aaa18ca70e8189ae6" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_bf7aeb42fe69427aaa18ca70e8189ae6" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_bf7aeb42fe69427aaa18ca70e8189ae6").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_bf7aeb42fe69427aaa18ca70e8189ae6");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_bf7aeb42fe69427aaa18ca70e8189ae6");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal continua solo puede tomar valores positivos.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_82cebd0965d1450ca626c1e087fc04b7" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_82cebd0965d1450ca626c1e087fc04b7" value="false">
#                 Falso
#             </label>
#
#             <button id="button_82cebd0965d1450ca626c1e087fc04b7" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_82cebd0965d1450ca626c1e087fc04b7" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_82cebd0965d1450ca626c1e087fc04b7").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_82cebd0965d1450ca626c1e087fc04b7");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_82cebd0965d1450ca626c1e087fc04b7");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señ
value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_0c7693b15ebf43dabdbc9bbda5bd3e00" value="false">
#                 Falso
#             </label>
#
#             <button id="button_0c7693b15ebf43dabdbc9bbda5bd3e00" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_0c7693b15ebf43dabdbc9bbda5bd3e00" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_0c7693b15ebf43dabdbc9bbda5bd3e00").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_0c7693b15ebf43dabdbc9bbda5bd3e00");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_0c7693b15ebf43dabdbc9bbda5bd3e00");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Las señales discretas siempre tienen amplitud entera.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_a378aaef44894c2984f02072db4a8154" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_a378aaef44894c2984f02072db4a8154" value="false">
#                 Falso
#             </label>
#
#             <button id="button_a378aaef44894c2984f02072db4a8154" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_a378aaef44894c2984f02072db4a8154" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_a378aaef44894c2984f02072db4a8154").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_a378aaef44894c2984f02072db4a8154");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_a378aaef44894c2984f02072db4a8154");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal sinusoidal continua puede ser periódica.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_494192ad96924ae088925f942986a52e" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_494192ad96924ae088925f942986a52e" value="false">
#                 Falso
#             </label>
#
#             <button id="button_494192ad96924ae088925f942986a52e" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_494192ad96924ae088925f942986a52e" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_494192ad96924ae088925f942986a52e").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_494192ad96924ae088925f942986a52e");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_494192ad96924ae088925f942986a52e");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal constante es aperiódica.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_c80815963ca346cfb8d05175f88e65fd" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_c80815963ca346cfb8d05175f88e65fd" value="false">
#                 Falso
#             </label>
#
#             <button id="button_c80815963ca346cfb8d05175f88e65fd" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_c80815963ca346cfb8d05175f88e65fd" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_c80815963ca346cfb8d05175f88e65fd").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_c80815963ca346cfb8d05175f88e65fd");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_c80815963ca346cfb8d05175f88e65fd");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor de la señal discreta $x[n]=\{1,3,5\}$ en $n=1$?

# %%
create_numeric_input_exercise(
    solution=3,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_30bb17ed1c724a85b672061807265711"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_30bb17ed1c724a85b672061807265711" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_30bb17ed1c724a85b672061807265711" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_30bb17ed1c724a85b672061807265711").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_30bb17ed1c724a85b672061807265711").value);
#
#         const feedback =
#             document.getElementById("feedback_30bb17ed1c724a85b672061807265711");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (3)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuántas muestras tiene la señal discreta $x[n]=\{1,2,3,4,5\}$?

# %%
create_numeric_input_exercise(
    solution=5,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_6c2eca7272ae41b29269afe28f42b189"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_6c2eca7272ae41b29269afe28f42b189" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_6c2eca7272ae41b29269afe28f42b189" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_6c2eca7272ae41b29269afe28f42b189").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_6c2eca7272ae41b29269afe28f42b189").value);
#
#         const feedback =
#             document.getElementById("feedback_6c2eca7272ae41b29269afe28f42b189");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (5)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué notación se utiliza normalmente para una señal continua?
#
# A. $x[n]$
# B. $x(t)$
# C. $X[k]$
# D. $h[n]$

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_93919dfb54d4411ba55756b078d9e160" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_93919dfb54d4411ba55756b078d9e160" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_93919dfb54d4411ba55756b078d9e160" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_93919dfb54d4411ba55756b078d9e160").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_93919dfb54d4411ba55756b078d9e160").value);
#
#         const feedback =
#             document.getElementById("feedback_93919dfb54d4411ba55756b078d9e160");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ## Parámetros de interés de las señales

# %%
create_true_false_exercise(
    statement="La energía de una señal siempre es positiva o nula.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal de energía tiene potencia media nula.",
    solution=True
)

create_true_false_exercise(
    statement="Las señales periódicas suelen clasificarse como señales de potencia.",
    solution=True
)

create_true_false_exercise(
    statement="El valor medio de una señal periódica siempre es cero.",
    solution=False
)

create_true_false_exercise(
    statement="El valor pico indica el máximo valor absoluto de una señal.",
    solution=True
)

create_true_false_exercise(
    statement="La potencia instantánea en una resistencia es proporcional al cuadrado de la corriente.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal de duración finita siempre tiene energía finita.",
    solution=True
)

create_true_false_exercise(
    statement="Las señales periódicas de potencia finita tienen energía total infinita.",
    solution=True
)

create_true_false_exercise(
    statement="El valor medio de una señal periódica puede ser distinto de cero.",
    solution=True
)

create_true_false_exercise(
    statement="La energía de una señal siempre es negativa.",
    solution=False
)

create_true_false_exercise(
    statement="La potencia media de una señal periódica ideal puede ser finita.",
    solution=True
)

create_true_false_exercise(
    statement="El valor medio de una señal impar periódica puede ser cero.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal con amplitud infinita siempre tiene potencia infinita.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>La energía de una señal siempre es positiva o nula.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_4358207169144cdaa5525af624351eb0" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_4358207169144cdaa5525af624351eb0" value="false">
#                 Falso
#             </label>
#
#             <button id="button_4358207169144cdaa5525af624351eb0" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_4358207169144cdaa5525af624351eb0" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4358207169144cdaa5525af624351eb0").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_4358207169144cdaa5525af624351eb0");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_4358207169144cdaa5525af624351eb0");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Una señal de energía tiene potencia media nula.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f139a31fe1e64106a9c0821f5e7f173f" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f139a31fe1e64106a9c0821f5e7f173f" value="false">
#                 Falso
#             </label>
#
#             <button id="button_f139a31fe1e64106a9c0821f5e7f173f" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_f139a31fe1e64106a9c0821f5e7f173f" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_f139a31fe1e64106a9c0821f5e7f173f").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_f139a31fe1e64106a9c0821f5e7f173f");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_f139a31fe1e64106a9c0821f5e7f173f");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Las señales periódicas suelen clasificarse como señales de potencia.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_e9a22ba924874befa477b43af5bf4fa0" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_e9a22ba924874befa477b43af5bf4fa0" value="false">
#                 Falso
#             </label>
#
#             <button id="button_e9a22ba924874befa477b43af5bf4fa0" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_e9a22ba924874befa477b43af5bf4fa0" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_e9a22ba924874befa477b43af5bf4fa0").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_e9a22ba924874befa477b43af5bf4fa0");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_e9a22ba924874befa477b43af5bf4fa0");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>El valor medio de una señal periódica siempre es cero.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_013806b9b4d84840b93681835a0568e6" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_013806b9b4d84840b93681835a0568e6" value="false">
#                 Falso
#             </label>
#
#             <button id="button_013806b9b4d84840b93681835a0568e6" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_013806b9b4d84840b93681835a0568e6" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_013806b9b4d84840b93681835a0568e6").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_013806b9b4d84840b93681835a0568e6");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_013806b9b4d84840b93681835a0568e6");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>El valor pico indica el máximo valor absoluto de una señal.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_4585aa91fbe548759cb7ad1049d7bcc8" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_4585aa91fbe548759cb7ad1049d7bcc8" value="false">
#                 Falso
#             </label>
#
#             <button id="button_4585aa91fbe548759cb7ad1049d7bcc8" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_4585aa91fbe548759cb7ad1049d7bcc8" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4585aa91fbe548759cb7ad1049d7bcc8").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_4585aa91fbe548759cb7ad1049d7bcc8");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_4585aa91fbe548759cb7ad1049d7bcc8");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>
style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_9957e6963d164a97bc3302d2145dcbb9" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_9957e6963d164a97bc3302d2145dcbb9").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_9957e6963d164a97bc3302d2145dcbb9");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_9957e6963d164a97bc3302d2145dcbb9");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es la energía de la señal discreta $x[n]=\{1,2,3\}$?

# %%
create_numeric_input_exercise(
    solution=14,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_6046b3e36598425c87fe52bd3570ab50"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_6046b3e36598425c87fe52bd3570ab50" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_6046b3e36598425c87fe52bd3570ab50" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_6046b3e36598425c87fe52bd3570ab50").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_6046b3e36598425c87fe52bd3570ab50").value);
#
#         const feedback =
#             document.getElementById("feedback_6046b3e36598425c87fe52bd3570ab50");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (14)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor medio de la señal discreta $x[n]=\{2,4,6\}$?

# %%
create_numeric_input_exercise(
    solution=4,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_ce4595e73f6b452b91c184fa4d8eb5f4"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_ce4595e73f6b452b91c184fa4d8eb5f4" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_ce4595e73f6b452b91c184fa4d8eb5f4" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_ce4595e73f6b452b91c184fa4d8eb5f4").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_ce4595e73f6b452b91c184fa4d8eb5f4").value);
#
#         const feedback =
#             document.getElementById("feedback_ce4595e73f6b452b91c184fa4d8eb5f4");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (4)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué parámetro indica el máximo valor absoluto de una señal?
#
# A. Energía
# B. Valor pico
# C. Potencia media
# D. Valor medio

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_cd70457651dc413fa551dbfcbd20e958" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_cd70457651dc413fa551dbfcbd20e958" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_cd70457651dc413fa551dbfcbd20e958" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_cd70457651dc413fa551dbfcbd20e958").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_cd70457651dc413fa551dbfcbd20e958").value);
#
#         const feedback =
#             document.getElementById("feedback_cd70457651dc413fa551dbfcbd20e958");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ## Sistemas continuos y discretos

# %%
create_true_false_exercise(
    statement="Un sistema transforma una señal de entrada en una señal de salida.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema continuo trabaja con señales continuas.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema discreto trabaja con señales discretas.",
    solution=True
)

create_true_false_exercise(
    statement="En un sistema, la salida nunca depende de la entrada.",
    solution=False
)

create_true_false_exercise(
    statement="El análisis de sistemas estudia la respuesta de un sistema a distintas entradas.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema transforma una señal de entrada en una señal de salida.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_b5e14a3a16d045fba97293440bc15588" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_b5e14a3a16d045fba97293440bc15588" value="false">
#                 Falso
#             </label>
#
#             <button id="button_b5e14a3a16d045fba97293440bc15588" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_b5e14a3a16d045fba97293440bc15588" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_b5e14a3a16d045fba97293440bc15588").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_b5e14a3a16d045fba97293440bc15588");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_b5e14a3a16d045fba97293440bc15588");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema continuo trabaja con señales continuas.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_0f2c41c1a6c74874b8bb0cd6ba7d11f0" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_0f2c41c1a6c74874b8bb0cd6ba7d11f0" value="false">
#                 Falso
#             </label>
#
#             <button id="button_0f2c41c1a6c74874b8bb0cd6ba7d11f0" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_0f2c41c1a6c74874b8bb0cd6ba7d11f0" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_0f2c41c1a6c74874b8bb0cd6ba7d11f0").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_0f2c41c1a6c74874b8bb0cd6ba7d11f0");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_0f2c41c1a6c74874b8bb0cd6ba7d11f0");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema discreto trabaja con señales discretas.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_ef7560f59bb1467d9ff2258bae24252e" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_ef7560f59bb1467d9ff2258bae24252e" value="false">
#                 Falso
#             </label>
#
#             <button id="button_ef7560f59bb1467d9ff2258bae24252e" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_ef7560f59bb1467d9ff2258bae24252e" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_ef7560f59bb1467d9ff2258bae24252e").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_ef7560f59bb1467d9ff2258bae24252e");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_ef7560f59bb1467d9ff2258bae24252e");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En un sistema, la salida nunca depende de la entrada.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_058a85c3f8944297857cf935bf0dbdc7" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_058a85c3f8944297857cf935bf0dbdc7" value="false">
#                 Falso
#             </label>
#
#             <button id="button_058a85c3f8944297857cf935bf0dbdc7" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_058a85c3f8944297857cf935bf0dbdc7" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_058a85c3f8944297857cf935bf0dbdc7").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_058a85c3f8944297857cf935bf0dbdc7");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_058a85c3f8944297857cf935bf0dbdc7");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>El análisis de sistemas estudia la respuesta de un sistema a distintas entradas.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d0b617c88ccc40b396eb2608e0366482" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d0b617c88ccc40b396eb2608e0366482" value="false">
#                 Falso
#             </label>
#
#             <button id="button_d0b617c88ccc40b396eb2608e0366482" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_d0b617c88ccc40b396eb2608e0366482" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d0b617c88ccc40b396eb2608e0366482").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_d0b617c88ccc40b396eb2608e0366482");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_d0b617c88ccc40b396eb2608e0366482");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y[n]=2x[n]$ y $x[0]=3$, ¿cuánto vale $y[0]$?

# %%
create_numeric_input_exercise(
    solution=6,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_97565aaaa1714acab255aeeef7006803"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_97565aaaa1714acab255aeeef7006803" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_97565aaaa1714acab255aeeef7006803" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_97565aaaa1714acab255aeeef7006803").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_97565aaaa1714acab255aeeef7006803").value);
#
#         const feedback =
#             document.getElementById("feedback_97565aaaa1714acab255aeeef7006803");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (6)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y(t)=x(t)+1$ y $x(t)=4$, ¿cuánto vale $y(t)$?

# %%
create_numeric_input_exercise(
    solution=5,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_4a0d5a4c44c1403b99a1796aa830d845"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_4a0d5a4c44c1403b99a1796aa830d845" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_4a0d5a4c44c1403b99a1796aa830d845" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4a0d5a4c44c1403b99a1796aa830d845").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_4a0d5a4c44c1403b99a1796aa830d845").value);
#
#         const feedback =
#             document.getElementById("feedback_4a0d5a4c44c1403b99a1796aa830d845");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (5)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué hace un sistema?
#
# A. Elimina señales
# B. Transforma señales
# C. Genera ruido únicamente
# D. Calcula derivadas siempre

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_48c070ae5fd6456aa957eef4c4ee24fd" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_48c070ae5fd6456aa957eef4c4ee24fd" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_48c070ae5fd6456aa957eef4c4ee24fd" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_48c070ae5fd6456aa957eef4c4ee24fd").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_48c070ae5fd6456aa957eef4c4ee24fd").value);
#
#         const feedback =
#             document.getElementById("feedback_48c070ae5fd6456aa957eef4c4ee24fd");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ## Señales elementales

# %%
create_true_false_exercise(
    statement="El escalón unitario continuo vale 0 para t<0.",
    solution=True
)

create_true_false_exercise(
    statement="La delta de Dirac tiene área unitaria.",
    solution=True
)

create_true_false_exercise(
    statement="La señal rampa es constante para todos los valores de tiempo.",
    solution=False
)

create_true_false_exercise(
    statement="La delta de Dirac es una función continua convencional.",
    solution=False
)

create_true_false_exercise(
    statement="El impulso unitario discreto vale 1 únicamente en n = 0.",
    solution=True
)

create_true_false_exercise(
    statement="La derivada del escalón unitario es el impulso unitario.",
    solution=True
)

create_true_false_exercise(
    statement="La integral de la delta de Dirac es el escalón unitario.",
    solution=True
)

create_true_false_exercise(
    statement="El escalón unitario discreto vale 1 para n ≥ 0.",
    solution=True
)

create_true_false_exercise(
    statement="Multiplicar una señal por una delta desplaza automáticamente la señal.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>
value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_fc77422415b740ceaa7002fd2ac5914e" value="false">
#                 Falso
#             </label>
#
#             <button id="button_fc77422415b740ceaa7002fd2ac5914e" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_fc77422415b740ceaa7002fd2ac5914e" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_fc77422415b740ceaa7002fd2ac5914e").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_fc77422415b740ceaa7002fd2ac5914e");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_fc77422415b740ceaa7002fd2ac5914e");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>El escalón unitario discreto vale 1 para n ≥ 0.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_b13fcab175cc4c299411ec935604c266" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_b13fcab175cc4c299411ec935604c266" value="false">
#                 Falso
#             </label>
#
#             <button id="button_b13fcab175cc4c299411ec935604c266" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_b13fcab175cc4c299411ec935604c266" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_b13fcab175cc4c299411ec935604c266").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_b13fcab175cc4c299411ec935604c266");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_b13fcab175cc4c299411ec935604c266");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Multiplicar una señal por una delta desplaza automáticamente la señal.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d87ba1b2949644d59b47fd82eb0d07ee" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d87ba1b2949644d59b47fd82eb0d07ee" value="false">
#                 Falso
#             </label>
#
#             <button id="button_d87ba1b2949644d59b47fd82eb0d07ee" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_d87ba1b2949644d59b47fd82eb0d07ee" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d87ba1b2949644d59b47fd82eb0d07ee").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_d87ba1b2949644d59b47fd82eb0d07ee");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_d87ba1b2949644d59b47fd82eb0d07ee");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor de $\delta[0]$?

# %%
create_numeric_input_exercise(
    solution=1,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_9d557a7a600d4472a05359a9d15f2b52"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_9d557a7a600d4472a05359a9d15f2b52" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_9d557a7a600d4472a05359a9d15f2b52" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_9d557a7a600d4472a05359a9d15f2b52").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_9d557a7a600d4472a05359a9d15f2b52").value);
#
#         const feedback =
#             document.getElementById("feedback_9d557a7a600d4472a05359a9d15f2b52");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (1)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor de $u[-2]$ para el escalón unitario discreto?

# %%
create_numeric_input_exercise(
    solution=0,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_020357a317224f2cbe61a07c3031823c"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_020357a317224f2cbe61a07c3031823c" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_020357a317224f2cbe61a07c3031823c" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_020357a317224f2cbe61a07c3031823c").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_020357a317224f2cbe61a07c3031823c").value);
#
#         const feedback =
#             document.getElementById("feedback_020357a317224f2cbe61a07c3031823c");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (0)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué señal vale 1 para $n=0$ y 0 para $n\neq 0$?
#
# A. Escalón unitario
# B. Impulso unitario discreto
# C. Señal rampa
# D. Señal sinusoidal

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_d816fe4110364411b1371125abc68bb8" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_d816fe4110364411b1371125abc68bb8" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_d816fe4110364411b1371125abc68bb8" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d816fe4110364411b1371125abc68bb8").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_d816fe4110364411b1371125abc68bb8").value);
#
#         const feedback =
#             document.getElementById("feedback_d816fe4110364411b1371125abc68bb8");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ## Propiedades básicas de los sistemas

# %%
create_true_false_exercise(
    statement="Un sistema sin memoria depende únicamente del valor actual de la entrada.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema causal puede depender de valores futuros de la entrada.",
    solution=False
)

create_true_false_exercise(
    statement="Un sistema estable produce una salida acotada para una entrada acotada.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema lineal cumple la propiedad de superposición.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema inversible permite recuperar la entrada a partir de la salida.",
    solution=True
)

create_true_false_exercise(
    statement="Todos los sistemas lineales son invariantes en el tiempo.",
    solution=False
)

create_true_false_exercise(
    statement="Un sistema puede ser causal e inestable al mismo tiempo.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema con memoria nunca puede ser causal.",
    solution=False
)

create_true_false_exercise(
    statement="Un sistema invariante en el tiempo responde igual aunque la entrada se desplace temporalmente.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema lineal siempre es físicamente realizable.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema sin memoria depende únicamente del valor actual de la entrada.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f57ce9e3f43440ab88f17cf2b196824f" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f57ce9e3f43440ab88f17cf2b196824f" value="false">
#                 Falso
#             </label>
#
#             <button id="button_f57ce9e3f43440ab88f17cf2b196824f" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_f57ce9e3f43440ab88f17cf2b196824f" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_f57ce9e3f43440ab88f17cf2b196824f").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_f57ce9e3f43440ab88f17cf2b196824f");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_f57ce9e3f43440ab88f17cf2b196824f");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema causal puede depender de valores futuros de la entrada.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_0a49ca799c7345acbeb100c8ad788721" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_0a49ca799c7345acbeb100c8ad788721" value="false">
#                 Falso
#             </label>
#
#             <button id="button_0a49ca799c7345acbeb100c8ad788721" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_0a49ca799c7345acbeb100c8ad788721" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_0a49ca799c7345acbeb100c8ad788721").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_0a49ca799c7345acbeb100c8ad788721");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_0a49ca799c7345acbeb100c8ad788721");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema estable produce una salida acotada para una entrada acotada.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_4e3661072ebb4efe80b9a0ceb83041f8" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_4e3661072ebb4efe80b9a0ceb83041f8" value="false">
#                 Falso
#             </label>
#
#             <button id="button_4e3661072ebb4efe80b9a0ceb83041f8" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_4e3661072ebb4efe80b9a0ceb83041f8" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4e3661072ebb4efe80b9a0ceb83041f8").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_4e3661072ebb4efe80b9a0ceb83041f8");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_4e3661072ebb4efe80b9a0ceb83041f8");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema lineal cumple la propiedad de superposición.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_e7f503580f134acf934329531b9260b6" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_e7f503580f134acf934329531b9260b6" value="false">
#                 Falso
#             </label>
#
#             <button id="button_e7f503580f134acf934329531b9260b6" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_e7f503580f134acf934329531b9260b6" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_e7f503580f134acf934329531b9260b6").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_e7f503580f134acf934329531b9260b6");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_e7f503580f134acf934329531b9260b6");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema inversible permite recuperar la entrada a partir de la salida.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_425ff14b8c394e599c8f3c677d54b6af" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_425ff14b8c394e599c8f3c677d54b6af" value="false">
#                 Falso
#             </label>
#
#             <button id="button_425ff14b8c394e599c8f3c677d54b6af" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_425ff14b8c394e599c8f3c677d54b6af" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_425ff14b8c394e599c8f3c677d54b6af").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_425ff14b8c394e599c8f3c677d54b6af");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_425ff14b8c394e599c8f3c677d54b6af");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Todos los sistemas lineales son invariantes en el tiempo.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_57c8fb69c3644232ad88a22605dbc510" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_57c8fb69c3644232ad88a22605dbc510" value="false">
#                 Falso
#             </label>
#
#             <button id="button_57c8fb69c3644232ad88a22605dbc510" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_57c8fb69c3644232ad88a22605dbc510" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_57c8fb69c3644232ad88a22605dbc510").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_57c8fb69c3644232ad88a22605dbc510");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_57c8fb69c3644232ad88a22605dbc510");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema puede ser causal e inestable al mismo tiempo.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bb4d89f87db944d39aec6c00a2468221" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bb4d89f87db944d39aec6c00a2468221" value="false">
#                 Falso
#             </label>
#
#             <button id="button_bb4d89f87db944d39aec6c00a2468221" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_bb4d89f87db944d39aec6c00a2468221" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_bb4d89f87db944d39aec6c00a2468221").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_bb4d89f87db944d39aec6c00a2468221");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_bb4d89f87db944d39aec6c00a2468221");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema con memoria nunca puede ser causal.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_ee0002ce9dc0447a8802b17e250a190e" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_ee0002ce9dc0447a8802b17e250a190e" value="false">
#                 Falso
#             </label>
#
#             <button id="button_ee0002ce9dc0447a8802b17e250a190e" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_ee0002ce9dc0447a8802b17e250a190e" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_ee0002ce9dc0447a8802b17e250a190e").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_ee0002ce9dc0447a8802b17e250a190e");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_ee0002ce9dc0447a8802b17e250a190e");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema invariante en el tiempo responde igual aunque la entrada se desplace temporalmente.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_26c21509c5a24aef85cbbe0d6db057c9" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_26c21509c5a24aef85cbbe0d6db057c9" value="false">
#                 Falso
#             </label>
#
#             <button id="button_26c21509c5a24aef85cbbe0d6db057c9" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_26c21509c5a24aef85cbbe0d6db057c9" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_26c21509c5a24aef85cbbe0d6db057c9").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_26c21509c5a24aef85cbbe0d6db057c9");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_26c21509c5a24aef85cbbe0d6db057c9");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema lineal siempre es físicamente realizable.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_3e23ce74a90e41429b72baccfcea0116" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_3e23ce74a90e41429b72baccfcea0116" value="false">
#                 Falso
#             </label>
#
#             <button id="button_3e23ce74a90e41429b72baccfcea0116" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_3e23ce74a90e41429b72baccfcea0116" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_3e23ce74a90e41429b72baccfcea0116").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_3e23ce74a90e41429b72baccfcea0116");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_3e23ce74a90e41429b72baccfcea0116");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y[n]=x[n]+2$ y $x[0]=5$, ¿cuánto vale $y[0]$?

# %%
create_numeric_input_exercise(
    solution=7,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_bcfaca3cefca4c94afd9ca9146e62e3e"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_bcfaca3cefca4c94afd9ca9146e62e3e" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_bcfaca3cefca4c94afd9ca9146e62e3e" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_bcfaca3cefca4c94afd9ca9146e62e3e").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_bcfaca3cefca4c94afd9ca9146e62e3e").value);
#
#         const feedback =
#             document.getElementById("feedback_bcfaca3cefca4c94afd9ca9146e62e3e");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (7)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y(t)=3x(t)$ y $x(t)=2$, ¿cuánto vale $y(t)$?

# %%
create_numeric_input_exercise(
    solution=6,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_d53f953a1ff54fa0bf1796d179dc3279"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_d53f953a1ff54fa0bf1796d179dc3279" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_d53f953a1ff54fa0bf1796d179dc3279" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d53f953a1ff54fa0bf1796d179dc3279").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_d53f953a1ff54fa0bf1796d179dc3279").value);
#
#         const feedback =
#             document.getElementById("feedback_d53f953a1ff54fa0bf1796d179dc3279");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (6)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué propiedad debe cumplir un sistema lineal?
#
# A. Periodicidad
# B. Superposición
# C. Energía infinita
# D. Memoria

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_25acb3ef26d94f19a0bdb45dd2627654" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_25acb3ef26d94f19a0bdb45dd2627654" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_25acb3ef26d94f19a0bdb45dd2627654" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_25acb3ef26d94f19a0bdb45dd2627654").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_25acb3ef26d94f19a0bdb45dd2627654").value);
#
#         const feedback =
#             document.getElementById("feedback_25acb3ef26d94f19a0bdb45dd2627654");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ## Interconexión de sistemas

# %%
create_true_false_exercise(
    statement="En una conexión en serie, la salida de un sistema es la entrada del siguiente.",
    solution=True
)

create_true_false_exercise(
    statement="En una conexión en paralelo, todos los sistemas reciben la misma entrada.",
    solution=True
)

create_true_false_exercise(
    statement="En una conexión en paralelo, las salidas de los sistemas se suman.",
    solution=True
)

create_true_false_exercise(
    statement="La realimentación utiliza parte de la salida del sistema.",
    solution=True
)

create_true_false_exercise(
    statement="En una interconexión en paralelo, las salidas de los sistemas se suman.",
    solution=True
)

create_true_false_exercise(
    statement="La realimentación consiste en conectar sistemas únicamente en serie.",
    solution=False
)

create_true_false_exercise(
    statement="En una conexión en cascada, la salida de un sistema alimenta al siguiente.",
    solution=True
)

create_true_false_exercise(
    statement="Dos sistemas lineales en cascada producen otro sistema lineal.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En una conexión en serie, la salida de un sistema es la entrada del siguiente.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_468d40b0f6f143e98323170b234fe3c6" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_468d40b0f6f143e98323170b234fe3c6" value="false">
#                 Falso
#             </label>
#
#             <button id="button_468d40b0f6f143e98323170b234fe3c6" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_468d40b0f6f143e98323170b234fe3c6" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_468d40b0f6f143e98323170b234fe3c6").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_468d40b0f6f143e98323170b234fe3c6");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_468d40b0f6f143e98323170b234fe3c6");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En una conexión en paralelo, todos los sistemas reciben la misma entrada.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f6edba971a704bb3b636556da746c12b" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f6edba971a704bb3b636556da746c12b" value="false">
#                 Falso
#             </label>
#
#             <button id="button_f6edba971a704bb3b636556da746c12b" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_f6edba971a704bb3b636556da746c12b" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_f6edba971a704bb3b636556da746c12b").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_f6edba971a704bb3b636556da746c12b");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_f6edba971a704bb3b636556da746c12b");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En una conexión en paralelo, las salidas de los sistemas se suman.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f6e9b5e97dd54605817d64f8f250b6b3" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_f6e9b5e97dd54605817d64f8f250b6b3" value="false">
#                 Falso
#             </label>
#
#             <button id="button_f6e9b5e97dd54605817d64f8f250b6b3" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_f6e9b5e97dd54605817d64f8f250b6b3" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_f6e9b5e97dd54605817d64f8f250b6b3").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_f6e9b5e97dd54605817d64f8f250b6b3");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_f6e9b5e97dd54605817d64f8f250b6b3");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>La realimentación utiliza parte de la salida del sistema.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d4eece30ae484ec688ace944c350db4d" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d4eece30ae484ec688ace944c350db4d" value="false">
#                 Falso
#             </label>
#
#             <button id="button_d4eece30ae484ec688ace944c350db4d" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_d4eece30ae484ec688ace944c350db4d" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d4eece30ae484ec688ace944c350db4d").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_d4eece30ae484ec688ace944c350db4d");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_d4eece30ae484ec688ace944c350db4d");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En una interconexión en paralelo, las salidas de los sistemas se suman.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_e7d0ab40f2d5455fb511664a6fb161f7" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_e7d0ab40f2d5455fb511664a6fb161f7" value="false">
#                 Falso
#             </label>
#
#             <button id="button_e7d0ab40f2d5455fb511664a6fb161f7" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_e7d0ab40f2d5455fb511664a6fb161f7" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_e7d0ab40f2d5455fb511664a6fb161f7").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_e7d0ab40f2d5455fb511664a6fb161f7");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_e7d0ab40f2d5455fb511664a6fb161f7");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>La realimentación consiste en conectar sistemas únicamente en serie.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d66f3a3b2b3843ce9c0d6044d53050ea" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d66f3a3b2b3843ce9c0d6044d53050ea" value="false">
#                 Falso
#             </label>
#
#             <button id="button_d66f3a3b2b3843ce9c0d6044d53050ea" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_d66f3a3b2b3843ce9c0d6044d53050ea" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d66f3a3b2b3843ce9c0d6044d53050ea").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_d66f3a3b2b3843ce9c0d6044d53050ea");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_d66f3a3b2b3843ce9c0d6044d53050ea");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En una conexión en cascada, la salida de un sistema alimenta al siguiente.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_9b127803e5f64d95a323c2d01028aead" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_9b127803e5f64d95a323c2d01028aead" value="false">
#                 Falso
#             </label>
#
#             <button id="button_9b127803e5f64d95a323c2d01028aead" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_9b127803e5f64d95a323c2d01028aead" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_9b127803e5f64d95a323c2d01028aead").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_9b127803e5f64d95a323c2d01028aead");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_9b127803e5f64d95a323c2d01028aead");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#         color:black;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Dos sistemas lineales en cascada producen otro sistema lineal.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_13d6eb3cb44e4980bc542b5a0e9c0a90" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_13d6eb3cb44e4980bc542b5a0e9c0a90" value="false">
#                 Falso
#             </label>
#
#             <button id="button_13d6eb3cb44e4980bc542b5a0e9c0a90" style="
#                 padding:4px 6px;
#                 border:1px solid #6c757d;
#                 border-radius:6px;
#                 background:#f8f9fa;
#                 color:#212529;
#                 cursor:pointer;
#             ">
#                 Evaluar
#             </button>
#
#             <span id="feedback_13d6eb3cb44e4980bc542b5a0e9c0a90" style="
#                 font-weight:bold;
#             "></span>
#         </div>
#
#     </div>
#
#     <script>
#     document.getElementById("button_13d6eb3cb44e4980bc542b5a0e9c0a90").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_13d6eb3cb44e4980bc542b5a0e9c0a90");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_13d6eb3cb44e4980bc542b5a0e9c0a90");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si en paralelo se suman dos señales y sus salidas son 3 y 5, ¿cuál es la salida total?

# %%
create_numeric_input_exercise(
    solution=8,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_9e4f1452e37346b5bbcf7ad31fa7763f"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_9e4f1452e37346b5bbcf7ad31fa7763f" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_9e4f1452e37346b5bbcf7ad31fa7763f" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_9e4f1452e37346b5bbcf7ad31fa7763f").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_9e4f1452e37346b5bbcf7ad31fa7763f").value);
#
#         const feedback =
#             document.getElementById("feedback_9e4f1452e37346b5bbcf7ad31fa7763f");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (8)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué tipo de conexión usa la salida de un sistema como entrada del siguiente?
#
# A. Paralelo
# B. Cascada
# C. Realimentación
# D. Muestreo

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_27823278cb69495c8275cc1d561f3cea" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_27823278cb69495c8275cc1d561f3cea" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_27823278cb69495c8275cc1d561f3cea" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_27823278cb69495c8275cc1d561f3cea").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_27823278cb69495c8275cc1d561f3cea").value);
#
#         const feedback =
#             document.getElementById("feedback_27823278cb69495c8275cc1d561f3cea");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
