# %% [markdown]
# # Ejercicios de autoevaluación

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from utils.test_helpers import create_answer_selector, create_numeric_input_exercise, create_true_false_exercise

# %% [markdown]
# ### Región de convergecia

# %%
create_true_false_exercise(
    statement=r"Si una señal tiene transformada Z con polos en \(z=2\) y \(z=-3\), si hay valores \(|z|>2\) en la ROC, la señal solamente puede tener valores no nulos en \(n \geq 0\).",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Si una señal tiene transformada Z con polos en \(z=2\) y \(z=-3\), si hay valores \(|z|>2\) en la ROC, la señal solamente puede tener valores no nulos en \(n \geq 0\).</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_28f40de72ee64de197d5619b9e24e793" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_28f40de72ee64de197d5619b9e24e793" value="false">
#                 Falso
#             </label>
#
# ...

# %%
create_true_false_exercise(
    statement=r"Si una señal tiene duración finita, la ROC de su transformada Z contiene todo el plano Z con posibles polos en 0 o infinito.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Si una señal tiene duración finita, la ROC de su transformada Z contiene todo el plano Z con posibles polos en 0 o infinito.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_95fb913df90c46018162314faedb561e" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_95fb913df90c46018162314faedb561e" value="false">
#                 Falso
#             </label>
#
# ...

# %%
create_true_false_exercise(
    statement=r"Solamente si la ROC de la transformada Z de una señal contiene la circunferencia unidad, la transformada de Fourier de dicha señal existe.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Solamente si la ROC de la transformada Z de una señal contiene la circunferencia unidad, la transformada de Fourier de dicha señal existe.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_8a876cfb5e6346c98942e8dd60e30b44" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_8a876cfb5e6346c98942e8dd60e30b44" value="false">
#                 Falso
#             </label>
#
# ...

# %%
create_true_false_exercise(
    statement=r"Cualquier señal en tiempo discreto tiene transformada Z con ROC no nula (conjunto vacío).",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Cualquier señal en tiempo discreto tiene transformada Z con ROC no nula (conjunto vacío).</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_3b83475267ae4e33913e757d89f819c6" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_3b83475267ae4e33913e757d89f819c6" value="false">
#                 Falso
#             </label>
#
#             <button id="button_3b83475267ae4e33913e757d89f819c6" style="
# ...

# %%
create_true_false_exercise(
    statement=r"Si una señal tiene valores no nulos solamente en \(n < 0 \) y varios polos reales, la ROC comprende todos los valores menores al polo de menor valor.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Si una señal tiene valores no nulos solamente en \(n < 0 \) y varios polos reales, la ROC comprende todos los valores menores al polo de menor valor.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_5bc6ebebfe4247abb1df27a441644c37" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_5bc6ebebfe4247abb1df27a441644c37" value="false">
#                 Falso
#             </label>
#
# ...

# %% [markdown]
# Si $X(z)$ es la transformada Z de una señal estable que tiene al menos un polo en $z=j/3$:
#
# A. ROC = $|z| < 1/3$.
#
# B. ROC = $|z| > 1/3$.
#
# C. La señal está necesariamente definida para tiempos positivos o el origen ($n \geq 0$) como negativos ($n<0$).
#
# D. Se necesita más información para determinar la ROC con exactitud.

# %%
create_answer_selector(
    num_options=4,
    solution=4,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_edd65b260b174dd5a06db5c70980002a" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_edd65b260b174dd5a06db5c70980002a" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_edd65b260b174dd5a06db5c70980002a" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
# ...

# %% [markdown]
# ### Transformada Z inversa

# %%
create_true_false_exercise(
    statement=r"La transformada Z inversa de una señal es única, independientemente de la ROC.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>La transformada Z inversa de una señal es única, independientemente de la ROC.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bb198b23f3ee4761981f52910b1f1b81" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bb198b23f3ee4761981f52910b1f1b81" value="false">
#                 Falso
#             </label>
#
#             <button id="button_bb198b23f3ee4761981f52910b1f1b81" style="
# ...

# %%
create_true_false_exercise(
    statement=r"En la ecuación de síntesis de la transformada Z, la integral se define solamente para circunferencias.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>En la ecuación de síntesis de la transformada Z, la integral se define solamente para circunferencias.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_071cd7be1a824a08b6373a5ec08e5ac5" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_071cd7be1a824a08b6373a5ec08e5ac5" value="false">
#                 Falso
#             </label>
#
# ...

# %% [markdown]
# Sea $X(z) = (1-az^{-1})^{-1}$, siendo $a \neq \{0,\infty\}$:
#
# A. Se puede determinar $x[n]$ y es única.
#
# B. Puede haber varias señales $x[n]$.
#
# C. $x[n]$ solamente puede definirse con valores no nulos para $n \geq 0$.
#
# D. $x[n]$ solamente puede definirse con valores no nulos para $n < 0$.

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_1713fa3556414595a94ada653bc8a855" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_1713fa3556414595a94ada653bc8a855" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_1713fa3556414595a94ada653bc8a855" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
# ...

# %% [markdown]
# ### Propiedades de la transformada Z

# %%
create_true_false_exercise(
    statement=r"Si la transformada Z de una señal \(x[n]\) es \(X(z)\), la transformada Z de \(x[-n]\) es \(X(-z)\).",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Si la transformada Z de una señal \(x[n]\) es \(X(z)\), la transformada Z de \(x[-n]\) es \(X(-z)\).</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_92a0b96ef86a40828e212e76249eebd8" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_92a0b96ef86a40828e212e76249eebd8" value="false">
#                 Falso
#             </label>
#
#             <button id="button_92a0b96ef86a40828e212e76249eebd8" style="
# ...

# %%
create_true_false_exercise(
    statement=r"Si la transformada Z de una señal \(x[n]\) es \(X(z)\), la transformada Z de \(x[n-2]\) es \(z^{-2} \cdot X(z)\).",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Si la transformada Z de una señal \(x[n]\) es \(X(z)\), la transformada Z de \(x[n-2]\) es \(z^{-2} \cdot X(z)\).</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d3fc1a9dcb424e55813841ab299c950d" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_d3fc1a9dcb424e55813841ab299c950d" value="false">
#                 Falso
#             </label>
#
# ...

# %% [markdown]
# Si una señal $x_1[n]$ tiene transformada Z $X_1(z)$ con ROC $= |z|>1$, y una señal $x_2[n]$ tiene transformada Z $X_2(z)$ con ROC $= |z| < 3$, respecto a la transformada Z de $x[n]=x_1[n]+x_2[n]$:
#
# A. Su ROC es un anillo.
# B. Su ROC es la intersección de la ROC de cada una de las dos señales, esto es, ROC $= 1 < |z| < 3$.
# C. $X(z)$ es la suma de las transformadas Z de cada una de las dos señales.
# D. Todas las opciones son correctas.

# %%
create_answer_selector(
    num_options=4,
    solution=4,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_733ac2f9b99c44a383899abbfc6f0fc5" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_733ac2f9b99c44a383899abbfc6f0fc5" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_733ac2f9b99c44a383899abbfc6f0fc5" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
# ...

# %% [markdown]
# ### Análisis de sistemas LTI

# %%
create_true_false_exercise(
    statement=r"Un sistema LTI es estable si \(|z|=1\) está incluida en la ROC de la función de transferencia, independientemente de su causalidad.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Un sistema LTI es estable si \(|z|=1\) está incluida en la ROC de la función de transferencia, independientemente de su causalidad.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bd1d0a8ec1e748ae8642269481c8d1f1" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_bd1d0a8ec1e748ae8642269481c8d1f1" value="false">
#                 Falso
#             </label>
#
# ...

# %%
create_true_false_exercise(
    statement=r"Al invertir un sistema LTI, los polos y ceros del sistema inverso con función de transferencia \(H_i(z)\) son los mismos que los del sistema original con función de transferencia \(H(z)\).",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Al invertir un sistema LTI, los polos y ceros del sistema inverso con función de transferencia \(H_i(z)\) son los mismos que los del sistema original con función de transferencia \(H(z)\).</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_433861644b314250a297394868e41047" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_433861644b314250a297394868e41047" value="false">
#                 Falso
# ...

# %%
create_true_false_exercise(
    statement=r"Si la ROC de la función de transferencia un sistema LTI es un anillo que no contiene el cero ni el infinito, el sistema es no causal.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <div style="margin-bottom: 15px;">
#             <span><strong>Si la ROC de la función de transferencia un sistema LTI es un anillo que no contiene el cero ni el infinito, el sistema es no causal.</strong></span>
#         </div>
#
#         <div style="
#             display:flex;
#             align-items:center;
#             gap:15px;
#             flex-wrap:wrap;
#         ">
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_fe5a0131fc2a4cb6bc04bae234eefbeb" value="true">
#                 Verdadero
#             </label>
#
#             <label style="cursor:pointer;">
#                 <input type="radio" name="radio_fe5a0131fc2a4cb6bc04bae234eefbeb" value="false">
#                 Falso
#             </label>
#
# ...

# %% [markdown]
# Si la función de transferencia de un sistema LTI tiene ROC $= |z| > 5$, respecto a la causalidad:
#
# A. El sistema es causal independientemente de sus polos y ceros.
#
# B. El sistema es anticausal independientemente de sus polos y ceros.
#
# C. El sistema es no causal si hay un polo en el infinito.
#
# D. Ninguna de las anteriores opciones es correcta.

# %%
create_answer_selector(
    num_options=4,
    solution=3,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_14838ae6542a43779cc7ec1ba1fdfc71" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_14838ae6542a43779cc7ec1ba1fdfc71" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_14838ae6542a43779cc7ec1ba1fdfc71" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
# ...

# %% [markdown]
# Si la función de transferencia de un sistema LTI tiene ROC $= |z| < 1/2$, respecto a la causalidad:
#
# A. El sistema es anticausal si tiene un cero en el origen.
#
# B. El sistema es causal si tiene un cero en el origen.
#
# C. El sistema es no causal independientemente de los ceros y polos.
#
# D. Ninguna de las anteriores opciones es correcta.

# %%
create_answer_selector(
    num_options=4,
    solution=1,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_1093f2e74fd546058d38abb79b8be571" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_1093f2e74fd546058d38abb79b8be571" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_1093f2e74fd546058d38abb79b8be571" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
# ...

# %% [markdown]
# Respecto al uso de la transformada Z para el análisis de sistemas LTI definidos mediante ecuaciones en diferencias:
#
# A. Se pueden analizar sistemas con diversas propiedades de estabilidad y causalidad.
#
# B. Se pueden analizar solamente sistemas estables y causales.
#
# C. Los sistemas analizados pueden ser solamente estables pero tener distintas propiedades de causalidad.
#
# D. Los sistemas analizados pueden ser solamente causales pero ser tanto estables como no estables.

# %%
create_answer_selector(
    num_options=4,
    solution=1,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_cf5692184e174da28854da48e40c90ba" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_cf5692184e174da28854da48e40c90ba" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_cf5692184e174da28854da48e40c90ba" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
# ...
