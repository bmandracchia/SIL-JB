# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## Ejercicios Resueltos
#
# ### Propiedades de los sistemas
#
# :::{warning .simple icon=false} Ejercicio 1
# Estudiar las propriedades del sistema $y(t)=e^{x(t)}$.
# :::
#
# :::{tip .simple icon=false class=dropdown} Solución del Ejercicio 1
# - **Memoria**
#
# 	La salida en cada instante de tiempo $t_0$ depende únicamente de la entrada en ese mismo instante: $y(t_0)=e^{x(t_0)},\ \forall t_0.\rightarrow\quad$ Sin memoria
#
# - **Causalidad**
#
# 	Todo sistema sin memoria es causal. $\rightarrow$ Causal.
#
# - **Invertibilidad**
#
# 	$w(t)=\ln(y(t))=x(t)$. Se obtiene una señal idéntica a la entrada para cualquier instante de tiempo. $\rightarrow$ Invertible.
#
# - **Estabilidad**
#
# 	Si $|x(t)|<B_x,\ \forall t\ \Rightarrow\ |y(t)|<e^{B_x}=B_y,\ \forall t.$ $\rightarrow$ Estable.
#
# - **Invarianza en el tiempo**
#
# 	Sea $x_1(t)$ una entrada arbitraria $\Rightarrow$ $y_1(t)=e^{x_1(t)}$.\
# 	Sea $x_2(t)=x_1(t-t_0)$ para un $t_0$ arbitrario $\Rightarrow$ $y_2(t)=e^{x_2(t)}=e^{x_1(t-t_0)}$.\
# 	Por otro lado: $y_1(t-t_0)=e^{x_1(t-t_0)}$.\
# 	Por tanto, se cumple que: $y_2(t)=y_1(t-t_0)$. $\rightarrow$ Invariante en el tiempo.
#
# - **Linealidad**
#
# 	Sean $x_1(t)$ y $x_2(t)$ entradas arbitrarias. $y_1(t)=e^{x_1(t)}$, $y_2(t)=e^{x_2(t)}$.\
# 	Sea $x_3(t)=\alpha x_1(t)+\beta x_2(t)$ una combinación lineal cualquiera de las entradas anteriores.\
# 	$y_3(t)=e^{x_3(t)}=e^{\alpha x_1(t)}e^{\beta x_2(t)}$.\
# 	Como $y_3(t)\neq \alpha e^{x_1(t)}+\beta e^{x_2(t)}$. $\rightarrow$ No lineal.
#
# Por tanto el sistema es \{-M,+C,+I,+E,+IT,-L\}.
# :::
#
#
# :::{warning .simple icon=false} Ejercicio 2
# Estudiar las propriedades del sistema $y[n]=x[n]x[n-1]$.
# :::
#
#
# :::{tip .simple class=dropdown icon=false} Solución del Ejercicio 2
#
# - **Memoria**
#
# 	La salida en cada instante de tiempo, $n_0$, depende de otro instante de tiempo distinto,\
# 	$n_0-1$.$\rightarrow$ Con memoria
#
# - **Causalidad**
#
# 	La salida en cada instante de tiempo, $n_0$, depende de la entrada en ese mismo instante (presente) y en el anterior, $n_0-1$, (pasado).$\rightarrow$ Causal.
#
# - **Invertibilidad**
#
# 	Contraejemplo: Sean dos entradas distintas, $x_1[n]$ nula para las muestras pares y $x_2[n]$ nula para las muestras impares, pero $y_1[n]=y_2[n]=0$.$\rightarrow$No invertible[^6].
#
# 	[^6]:Otro contraejemplo sencillo es: $x_2[n]=-x_1[n]\ \Rightarrow\ y_2[n]=y_1[n]$.
#
# - **Estabilidad**
#
# 	Si $|x[n]|<B_x,\ \forall n\ \Rightarrow\ |y[n]|<B_x^2=B_y,\ \forall n.$ $\rightarrow$ Estable.
#
# - **Invarianza en el tiempo**
#
# 	Sea $x_1[n]$ una entrada arbitraria $\Rightarrow$ $y_1[n]=x_1[n]x_1[n-1]$.\
# 	Sea $x_2[n]=x_1[n-n_0]$ para un $n_0$ arbitrario\
# 	$\quad\Rightarrow$ $y_2[n]=x_2[n]x_2[n-1]=x_1[n-n_0]x_1[n-n_0-1]$.\
# 	Por otro lado: $y_1[n-n_0]=x_1[n-n_0]x_1[n-n_0-1]$.\
# 	Por tanto, se cumple que: $y_2[n]=y_1[n-n_0]$.$\rightarrow$ Invariante en el tiempo.
#
# - **Linealidad**
#
# 	Sean $x_1[n]$ y $x_2[n]$ entradas arbitrarias.\
# 	$y_1[n]=x_1[n]x_1[n-1]$, $y_2[n]=x_2[n]x_2[n-1]$.\
# 	Sea $x_3[n]=\alpha x_1[n]+\beta x_2[n]$ una combinación lineal cualquiera de las entradas anteriores.
# 	$y_3[n]=x_3[n]x_3[n-1]=(\alpha x_1[n]+\beta x_2[n])(\alpha x_1[n-1]+\beta x_2[n-1])$\
# 	$y_3[n]=\alpha^2 x_1[n]x_1[n-1]+\alpha\beta x_1[n]x_2[n-1]+\alpha\beta x_1[n-1]x_2[n]+\beta^2 x_2[n]x_2[n-1]$.\
# 	Como $y_3[n]\neq \alpha y_1[n]+\beta y_2[n]=\alpha x_1[n]x_1[n-1]+\beta x_2[n]x_2[n-1]$.$\rightarrow$ No lineal.
#
# Por tanto el sistema es \{+M,+C,-I,+E,+IT,-L\}.
# :::

# %% [markdown]
# ## Ejercicios de Autoevaluación

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from utils.test_helpers import create_answer_selector, create_numeric_input_exercise, create_true_false_exercise

# %% [markdown]
# ### Señales continuas y discretas

# %%
create_true_false_exercise(
    statement="Una señal continua se representa normalmente como x(t).",
    solution=True
)

create_true_false_exercise(
    statement="Una señal discreta se representa normalmente como x[n].",
    solution=True
)

create_true_false_exercise(
    statement="Una señal discreta está definida para valores enteros de la variable independiente.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal continua solo puede tomar valores positivos.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal discreta puede representarse mediante diagramas de tallos.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal periódica siempre tiene energía finita.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal continua se representa normalmente como x[n].",
    solution=False
)

create_true_false_exercise(
    statement="Una señal discreta solo está definida para valores enteros de la variable independiente.",
    solution=True
)

create_true_false_exercise(
    statement="El valor pico de una señal puede ser negativo.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal impar cumple x(-t) = x(t).",
    solution=False
)

create_true_false_exercise(
    statement="Una señal par cumple x(-t)=x(t).",
    solution=True
)

create_true_false_exercise(
    statement="Una señal puede representar información física.",
    solution=True
)

create_true_false_exercise(
    statement="Las señales discretas siempre tienen amplitud entera.",
    solution=False
)

create_true_false_exercise(
    statement="Una señal sinusoidal continua puede ser periódica.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal constante es aperiódica.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal continua se representa normalmente como x(t).</strong></span>
#
#         <label>
#             <input type="radio" name="radio_81713b2aed584d61bf694491b60d4f96" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_81713b2aed584d61bf694491b60d4f96" value="false">
#             Falso
#         </label>
#
#         <button id="button_81713b2aed584d61bf694491b60d4f96" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_81713b2aed584d61bf694491b60d4f96" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_81713b2aed584d61bf694491b60d4f96").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_81713b2aed584d61bf694491b60d4f96");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_81713b2aed584d61bf694491b60d4f96");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal discreta se representa normalmente como x[n].</strong></span>
#
#         <label>
#             <input type="radio" name="radio_f158c46ddec44210a225bbdac1fdde21" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_f158c46ddec44210a225bbdac1fdde21" value="false">
#             Falso
#         </label>
#
#         <button id="button_f158c46ddec44210a225bbdac1fdde21" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_f158c46ddec44210a225bbdac1fdde21" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_f158c46ddec44210a225bbdac1fdde21").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_f158c46ddec44210a225bbdac1fdde21");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_f158c46ddec44210a225bbdac1fdde21");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal discreta está definida para valores enteros de la variable independiente.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_8d49720be79a4c11abca2597527ea02c" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_8d49720be79a4c11abca2597527ea02c" value="false">
#             Falso
#         </label>
#
#         <button id="button_8d49720be79a4c11abca2597527ea02c" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_8d49720be79a4c11abca2597527ea02c" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_8d49720be79a4c11abca2597527ea02c").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_8d49720be79a4c11abca2597527ea02c");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_8d49720be79a4c11abca2597527ea02c");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal continua solo puede tomar valores positivos.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_8a68d97199954817bf374026afb33b10" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_8a68d97199954817bf374026afb33b10" value="false">
#             Falso
#         </label>
#
#         <button id="button_8a68d97199954817bf374026afb33b10" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_8a68d97199954817bf374026afb33b10" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_8a68d97199954817bf374026afb33b10").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_8a68d97199954817bf374026afb33b10");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_8a68d97199954817bf374026afb33b10");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal discreta puede representarse mediante diagramas de tallos.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_1e94db3a1ae14bd2b585ad9a5f07e918" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_1e94db3a1ae14bd2b585ad9a5f07e918" value="false">
#             Falso
#         </label>
#
#         <button id="button_1e94db3a1ae14bd2b585ad9a5f07e918" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_1e94db3a1ae14bd2b585ad9a5f07e918" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_1e94db3a1ae14bd2b585ad9a5f07e918").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_1e94db3a1ae14bd2b585ad9a5f07e918");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_1e94db3a1ae14bd2b585ad9a5f07e918");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal periódica siempre tiene energía finita.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_67bc7b0a1a6c40ba92fe04f58b4319c1" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_67bc7b0a1a6c40ba92fe04f58b4319c1" value="false">
#             Falso
#         </label>
#
#         <button id="button_67bc7b0a1a6c40ba92fe04f58b4319c1" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_67bc7b0a1a6c40ba92fe04f58b4319c1" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_67bc7b0a1a6c40ba92fe04f58b4319c1").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_67bc7b0a1a6c40ba92fe04f58b4319c1");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_67bc7b0a1a6c40ba92fe04f58b4319c1");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal continua se representa normalmente como x[n].</strong></span>
#
#         <label>
#             <input type="radio" name="radio_874f92149d494cfeac3b36558a1f0b83" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_874f92149d494cfeac3b36558a1f0b83" value="false">
#             Falso
#         </label>
#
#         <button id="button_874f92149d494cfeac3b36558a1f0b83" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_874f92149d494cfeac3b36558a1f0b83" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_874f92149d494cfeac3b36558a1f0b83").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_874f92149d494cfeac3b36558a1f0b83");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_874f92149d494cfeac3b36558a1f0b83");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal discreta solo está definida para valores enteros de la variable independiente.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_39087bf9d6b04cfa8bd6411a60360829" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_39087bf9d6b04cfa8bd6411a60360829" value="false">
#             Falso
#         </label>
#
#         <button id="button_39087bf9d6b04cfa8bd6411a60360829" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_39087bf9d6b04cfa8bd6411a60360829" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_39087bf9d6b04cfa8bd6411a60360829").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_39087bf9d6b04cfa8bd6411a60360829");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_39087bf9d6b04cfa8bd6411a60360829");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>El valor pico de una señal puede ser negativo.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_ae190b9cd3694a77b08aa4fe557d9207" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_ae190b9cd3694a77b08aa4fe557d9207" value="false">
#             Falso
#         </label>
#
#         <button id="button_ae190b9cd3694a77b08aa4fe557d9207" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_ae190b9cd3694a77b08aa4fe557d9207" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_ae190b9cd3694a77b08aa4fe557d9207").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_ae190b9cd3694a77b08aa4fe557d9207");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_ae190b9cd3694a77b08aa4fe557d9207");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal impar cumple x(-t) = x(t).</strong></span>
#
#         <label>
#             <input type="radio" name="radio_fb347a2e0d8247b380729d73f61c5e61" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_fb347a2e0d8247b380729d73f61c5e61" value="false">
#             Falso
#         </label>
#
#         <button id="button_fb347a2e0d8247b380729d73f61c5e61" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_fb347a2e0d8247b380729d73f61c5e61" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_fb347a2e0d8247b380729d73f61c5e61").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_fb347a2e0d8247b380729d73f61c5e61");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_fb347a2e0d8247b380729d73f61c5e61");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal par cumple x(-t)=x(t).</strong></span>
#
#         <label>
#             <input type="radio" name="radio_9ad968b4bad24778863caafcdaf6a360" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_9ad968b4bad24778863caafcdaf6a360" value="false">
#             Falso
#         </label>
#
#         <button id="button_9ad968b4bad24778863caafcdaf6a360" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_9ad968b4bad24778863caafcdaf6a360" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_9ad968b4bad24778863caafcdaf6a360").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_9ad968b4bad24778863caafcdaf6a360");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_9ad968b4bad24778863caafcdaf6a360");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal puede representar información física.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_89f4027b2af64efeb9fba08d6c6808e0" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_89f4027b2af64efeb9fba08d6c6808e0" value="false">
#             Falso
#         </label>
#
#         <button id="button_89f4027b2af64efeb9fba08d6c6808e0" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_89f4027b2af64efeb9fba08d6c6808e0" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_89f4027b2af64efeb9fba08d6c6808e0").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_89f4027b2af64efeb9fba08d6c6808e0");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_89f4027b2af64efeb9fba08d6c6808e0");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Las señales discretas siempre tienen amplitud entera.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_28c07a78b8384f198c2be3fe7d3a2428" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_28c07a78b8384f198c2be3fe7d3a2428" value="false">
#             Falso
#         </label>
#
#         <button id="button_28c07a78b8384f198c2be3fe7d3a2428" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_28c07a78b8384f198c2be3fe7d3a2428" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_28c07a78b8384f198c2be3fe7d3a2428").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_28c07a78b8384f198c2be3fe7d3a2428");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_28c07a78b8384f198c2be3fe7d3a2428");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal sinusoidal continua puede ser periódica.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_fc3071d6e82b43a58e9a7b9ac1717efa" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_fc3071d6e82b43a58e9a7b9ac1717efa" value="false">
#             Falso
#         </label>
#
#         <button id="button_fc3071d6e82b43a58e9a7b9ac1717efa" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_fc3071d6e82b43a58e9a7b9ac1717efa" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_fc3071d6e82b43a58e9a7b9ac1717efa").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_fc3071d6e82b43a58e9a7b9ac1717efa");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_fc3071d6e82b43a58e9a7b9ac1717efa");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal constante es aperiódica.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_a38a55ced90e46c397144f8e57637718" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_a38a55ced90e46c397144f8e57637718" value="false">
#             Falso
#         </label>
#
#         <button id="button_a38a55ced90e46c397144f8e57637718" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_a38a55ced90e46c397144f8e57637718" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_a38a55ced90e46c397144f8e57637718").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_a38a55ced90e46c397144f8e57637718");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_a38a55ced90e46c397144f8e57637718");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor de la señal discreta $x[n]=\{1,3,5\}$ en $n=1$?

# %%
create_numeric_input_exercise(
    solution=3,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_99611169eb0445ed866cd22de1b6dbdd"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_99611169eb0445ed866cd22de1b6dbdd" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_99611169eb0445ed866cd22de1b6dbdd" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_99611169eb0445ed866cd22de1b6dbdd").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_99611169eb0445ed866cd22de1b6dbdd").value);
#
#         const feedback =
#             document.getElementById("feedback_99611169eb0445ed866cd22de1b6dbdd");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (3)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuántas muestras tiene la señal discreta $x[n]=\{1,2,3,4,5\}$?

# %%
create_numeric_input_exercise(
    solution=5,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_d0cdad85207c4a53a6a4502c821f2140"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_d0cdad85207c4a53a6a4502c821f2140" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_d0cdad85207c4a53a6a4502c821f2140" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d0cdad85207c4a53a6a4502c821f2140").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_d0cdad85207c4a53a6a4502c821f2140").value);
#
#         const feedback =
#             document.getElementById("feedback_d0cdad85207c4a53a6a4502c821f2140");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (5)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué notación se utiliza normalmente para una señal continua?
#
# A. $x[n]$
# B. $x(t)$
# C. $X[k]$
# D. $h[n]$

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_593ef85a0039440788c29a828fb3b604" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_593ef85a0039440788c29a828fb3b604" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_593ef85a0039440788c29a828fb3b604" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_593ef85a0039440788c29a828fb3b604").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_593ef85a0039440788c29a828fb3b604").value);
#
#         const feedback =
#             document.getElementById("feedback_593ef85a0039440788c29a828fb3b604");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ### Parámetros de interés de las señales

# %%
create_true_false_exercise(
    statement="La energía de una señal siempre es positiva o nula.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal de energía tiene potencia media nula.",
    solution=True
)

create_true_false_exercise(
    statement="Las señales periódicas suelen clasificarse como señales de potencia.",
    solution=True
)

create_true_false_exercise(
    statement="El valor medio de una señal periódica siempre es cero.",
    solution=False
)

create_true_false_exercise(
    statement="El valor pico indica el máximo valor absoluto de una señal.",
    solution=True
)

create_true_false_exercise(
    statement="La potencia instantánea en una resistencia es proporcional al cuadrado de la corriente.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal de duración finita siempre tiene energía finita.",
    solution=True
)

create_true_false_exercise(
    statement="Las señales periódicas de potencia finita tienen energía total infinita.",
    solution=True
)

create_true_false_exercise(
    statement="El valor medio de una señal periódica puede ser distinto de cero.",
    solution=True
)

create_true_false_exercise(
    statement="La energía de una señal siempre es negativa.",
    solution=False
)

create_true_false_exercise(
    statement="La potencia media de una señal periódica ideal puede ser finita.",
    solution=True
)

create_true_false_exercise(
    statement="El valor medio de una señal impar periódica puede ser cero.",
    solution=True
)

create_true_false_exercise(
    statement="Una señal con amplitud infinita siempre tiene potencia infinita.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>La energía de una señal siempre es positiva o nula.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_ae74696f1da74d819433045e74eca428" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_ae74696f1da74d819433045e74eca428" value="false">
#             Falso
#         </label>
#
#         <button id="button_ae74696f1da74d819433045e74eca428" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_ae74696f1da74d819433045e74eca428" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_ae74696f1da74d819433045e74eca428").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_ae74696f1da74d819433045e74eca428");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_ae74696f1da74d819433045e74eca428");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Una señal de energía tiene potencia media nula.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_eceebec54d9146cdb9df5d09a4fbe789" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_eceebec54d9146cdb9df5d09a4fbe789" value="false">
#             Falso
#         </label>
#
#         <button id="button_eceebec54d9146cdb9df5d09a4fbe789" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_eceebec54d9146cdb9df5d09a4fbe789" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_eceebec54d9146cdb9df5d09a4fbe789").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_eceebec54d9146cdb9df5d09a4fbe789");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_eceebec54d9146cdb9df5d09a4fbe789");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Las señales periódicas suelen clasificarse como señales de potencia.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_b73a0e89ca054c44a46d6a8515173684" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_b73a0e89ca054c44a46d6a8515173684" value="false">
#             Falso
#         </label>
#
#         <button id="button_b73a0e89ca054c44a46d6a8515173684" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_b73a0e89ca054c44a46d6a8515173684" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_b73a0e89ca054c44a46d6a8515173684").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_b73a0e89ca054c44a46d6a8515173684");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_b73a0e89ca054c44a46d6a8515173684");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>El valor medio de una señal periódica siempre es cero.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_3d0777e3397041b88b7e8b50ebed567b" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_3d0777e3397041b88b7e8b50ebed567b" value="false">
#             Falso
#         </label>
#
#         <button id="button_3d0777e3397041b88b7e8b50ebed567b" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_3d0777e3397041b88b7e8b50ebed567b" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_3d0777e3397041b88b7e8b50ebed567b").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_3d0777e3397041b88b7e8b50ebed567b");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_3d0777e3397041b88b7e8b50ebed567b");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>El valor pico indica el máximo valor absoluto de una señal.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_ccdb725dc2d747aeb5ca5a87a1ff0ba9" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_ccdb725dc2d747aeb5ca5a87a1ff0ba9" value="false">
#             Falso
#         </label>
#
#         <button id="button_ccdb725dc2d747aeb5ca5a87a1ff0ba9" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_ccdb725dc2d747aeb5ca5a87a1ff0ba9" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_ccdb725dc2d747aeb5ca5a87a1ff0ba9").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_ccdb725dc2d747aeb5ca5a87a1ff0ba9");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_ccdb725dc2d747aeb5ca5a87a1ff0ba9");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es la energía de la señal discreta $x[n]=\{1,2,3\}$?

# %%
create_numeric_input_exercise(
    solution=14,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_33ba05efde274a1c81f64d9f43f6e521"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_33ba05efde274a1c81f64d9f43f6e521" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_33ba05efde274a1c81f64d9f43f6e521" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_33ba05efde274a1c81f64d9f43f6e521").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_33ba05efde274a1c81f64d9f43f6e521").value);
#
#         const feedback =
#             document.getElementById("feedback_33ba05efde274a1c81f64d9f43f6e521");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (14)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor medio de la señal discreta $x[n]=\{2,4,6\}$?

# %%
create_numeric_input_exercise(
    solution=4,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_113f87582a194dd99875da4fff1830b1"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_113f87582a194dd99875da4fff1830b1" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_113f87582a194dd99875da4fff1830b1" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_113f87582a194dd99875da4fff1830b1").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_113f87582a194dd99875da4fff1830b1").value);
#
#         const feedback =
#             document.getElementById("feedback_113f87582a194dd99875da4fff1830b1");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (4)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué parámetro indica el máximo valor absoluto de una señal?
#
# A. Energía
# B. Valor pico
# C. Potencia media
# D. Valor medio

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_694704daf6a6458cb2422c259261da5d" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_694704daf6a6458cb2422c259261da5d" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_694704daf6a6458cb2422c259261da5d" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_694704daf6a6458cb2422c259261da5d").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_694704daf6a6458cb2422c259261da5d").value);
#
#         const feedback =
#             document.getElementById("feedback_694704daf6a6458cb2422c259261da5d");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ### Sistemas continuos y discretos

# %%
create_true_false_exercise(
    statement="Un sistema transforma una señal de entrada en una señal de salida.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema continuo trabaja con señales continuas.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema discreto trabaja con señales discretas.",
    solution=True
)

create_true_false_exercise(
    statement="En un sistema, la salida nunca depende de la entrada.",
    solution=False
)

create_true_false_exercise(
    statement="El análisis de sistemas estudia la respuesta de un sistema a distintas entradas.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema transforma una señal de entrada en una señal de salida.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_75d1aa428d02473392ff30507da8b04a" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_75d1aa428d02473392ff30507da8b04a" value="false">
#             Falso
#         </label>
#
#         <button id="button_75d1aa428d02473392ff30507da8b04a" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_75d1aa428d02473392ff30507da8b04a" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_75d1aa428d02473392ff30507da8b04a").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_75d1aa428d02473392ff30507da8b04a");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_75d1aa428d02473392ff30507da8b04a");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema continuo trabaja con señales continuas.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_77017b4d398a4663bdbc7be60a3cf588" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_77017b4d398a4663bdbc7be60a3cf588" value="false">
#             Falso
#         </label>
#
#         <button id="button_77017b4d398a4663bdbc7be60a3cf588" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_77017b4d398a4663bdbc7be60a3cf588" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_77017b4d398a4663bdbc7be60a3cf588").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_77017b4d398a4663bdbc7be60a3cf588");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_77017b4d398a4663bdbc7be60a3cf588");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema discreto trabaja con señales discretas.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_e6c69a2b4ab446349fd76ff36e544bb1" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_e6c69a2b4ab446349fd76ff36e544bb1" value="false">
#             Falso
#         </label>
#
#         <button id="button_e6c69a2b4ab446349fd76ff36e544bb1" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_e6c69a2b4ab446349fd76ff36e544bb1" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_e6c69a2b4ab446349fd76ff36e544bb1").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_e6c69a2b4ab446349fd76ff36e544bb1");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_e6c69a2b4ab446349fd76ff36e544bb1");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>En un sistema, la salida nunca depende de la entrada.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_b2cec4d13fe0436681a77428da0f8ad2" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_b2cec4d13fe0436681a77428da0f8ad2" value="false">
#             Falso
#         </label>
#
#         <button id="button_b2cec4d13fe0436681a77428da0f8ad2" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_b2cec4d13fe0436681a77428da0f8ad2" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_b2cec4d13fe0436681a77428da0f8ad2").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_b2cec4d13fe0436681a77428da0f8ad2");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_b2cec4d13fe0436681a77428da0f8ad2");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>El análisis de sistemas estudia la respuesta de un sistema a distintas entradas.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_3ff98f6b0a894bf0820a481cb2760d0b" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_3ff98f6b0a894bf0820a481cb2760d0b" value="false">
#             Falso
#         </label>
#
#         <button id="button_3ff98f6b0a894bf0820a481cb2760d0b" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_3ff98f6b0a894bf0820a481cb2760d0b" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_3ff98f6b0a894bf0820a481cb2760d0b").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_3ff98f6b0a894bf0820a481cb2760d0b");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_3ff98f6b0a894bf0820a481cb2760d0b");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y[n]=2x[n]$ y $x[0]=3$, ¿cuánto vale $y[0]$?

# %%
create_numeric_input_exercise(
    solution=6,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_359171879d6143798e3e62876e1eb01a"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_359171879d6143798e3e62876e1eb01a" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_359171879d6143798e3e62876e1eb01a" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_359171879d6143798e3e62876e1eb01a").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_359171879d6143798e3e62876e1eb01a").value);
#
#         const feedback =
#             document.getElementById("feedback_359171879d6143798e3e62876e1eb01a");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (6)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y(t)=x(t)+1$ y $x(t)=4$, ¿cuánto vale $y(t)$?

# %%
create_numeric_input_exercise(
    solution=5,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_40cd0434f5154edcad99d78296129334"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_40cd0434f5154edcad99d78296129334" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_40cd0434f5154edcad99d78296129334" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_40cd0434f5154edcad99d78296129334").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_40cd0434f5154edcad99d78296129334").value);
#
#         const feedback =
#             document.getElementById("feedback_40cd0434f5154edcad99d78296129334");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (5)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué hace un sistema?
#
# A. Elimina señales
# B. Transforma señales
# C. Genera ruido únicamente
# D. Calcula derivadas siempre

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_7c6e4df6b569413a8aa99331fc4c2984" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_7c6e4df6b569413a8aa99331fc4c2984" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_7c6e4df6b569413a8aa99331fc4c2984" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_7c6e4df6b569413a8aa99331fc4c2984").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_7c6e4df6b569413a8aa99331fc4c2984").value);
#
#         const feedback =
#             document.getElementById("feedback_7c6e4df6b569413a8aa99331fc4c2984");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ### Señales elementales

# %%
create_true_false_exercise(
    statement="El escalón unitario continuo vale 0 para t<0.",
    solution=True
)

create_true_false_exercise(
    statement="La delta de Dirac tiene área unitaria.",
    solution=True
)

create_true_false_exercise(
    statement="La señal rampa es constante para todos los valores de tiempo.",
    solution=False
)

create_true_false_exercise(
    statement="La delta de Dirac es una función continua convencional.",
    solution=False
)

create_true_false_exercise(
    statement="El impulso unitario discreto vale 1 únicamente en n = 0.",
    solution=True
)

create_true_false_exercise(
    statement="La derivada del escalón unitario es el impulso unitario.",
    solution=True
)

create_true_false_exercise(
    statement="La integral de la delta de Dirac es el escalón unitario.",
    solution=True
)

create_true_false_exercise(
    statement="El escalón unitario discreto vale 1 para n ≥ 0.",
    solution=True
)

create_true_false_exercise(
    statement="Multiplicar una señal por una delta desplaza automáticamente la señal.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>El impulso unitario discreto vale 1 en n=0 y 0 en el resto de valores.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_49e5dd6e5fb94103a5a1a744f57b19da" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_49e5dd6e5fb94103a5a1a744f57b19da" value="false">
#             Falso
#         </label>
#
#         <button id="button_49e5dd6e5fb94103a5a1a744f57b19da" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_49e5dd6e5fb94103a5a1a744f57b19da" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_49e5dd6e5fb94103a5a1a744f57b19da").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_49e5dd6e5fb94103a5a1a744f57b19da");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_49e5dd6e5fb94103a5a1a744f57b19da");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>El escalón unitario continuo vale 0 para t<0.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_3797ce08ec8043f7a62ac43ee48effdc" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_3797ce08ec8043f7a62ac43ee48effdc" value="false">
#             Falso
#         </label>
#
#         <button id="button_3797ce08ec8043f7a62ac43ee48effdc" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_3797ce08ec8043f7a62ac43ee48effdc" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_3797ce08ec8043f7a62ac43ee48effdc").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_3797ce08ec8043f7a62ac43ee48effdc");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_3797ce08ec8043f7a62ac43ee48effdc");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>La delta de Dirac tiene área unitaria.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_dfddc876b78547fca2444d16f78d4f8b" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_dfddc876b78547fca2444d16f78d4f8b" value="false">
#             Falso
#         </label>
#
#         <button id="button_dfddc876b78547fca2444d16f78d4f8b" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_dfddc876b78547fca2444d16f78d4f8b" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_dfddc876b78547fca2444d16f78d4f8b").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_dfddc876b78547fca2444d16f78d4f8b");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_dfddc876b78547fca2444d16f78d4f8b");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>La derivada del escalón unitario es la delta de Dirac.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_be2449bb449c4073a0761627d851f8b1" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_be2449bb449c4073a0761627d851f8b1" value="false">
#             Falso
#         </label>
#
#         <button id="button_be2449bb449c4073a0761627d851f8b1" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_be2449bb449c4073a0761627d851f8b1" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_be2449bb449c4073a0761627d851f8b1").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_be2449bb449c4073a0761627d851f8b1");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_be2449bb449c4073a0761627d851f8b1");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>La señal rampa es constante para todos los valores de tiempo.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_194cdb3534284da5a663ecd2f21f8209" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_194cdb3534284da5a663ecd2f21f8209" value="false">
#             Falso
#         </label>
#
#         <button id="button_194cdb3534284da5a663ecd2f21f8209" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_194cdb3534284da5a663ecd2f21f8209" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_194cdb3534284da5a663ecd2f21f8209").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_194cdb3534284da5a663ecd2f21f8209");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_194cdb3534284da5a663ecd2f21f8209");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor de $\delta[0]$?

# %%
create_numeric_input_exercise(
    solution=1,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_4aae9c831fee413692af64b635e51ae5"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_4aae9c831fee413692af64b635e51ae5" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_4aae9c831fee413692af64b635e51ae5" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4aae9c831fee413692af64b635e51ae5").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_4aae9c831fee413692af64b635e51ae5").value);
#
#         const feedback =
#             document.getElementById("feedback_4aae9c831fee413692af64b635e51ae5");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (1)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Cuál es el valor de $u[-2]$ para el escalón unitario discreto?

# %%
create_numeric_input_exercise(
    solution=0,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_4c6ab977fc6543f4810d52baaae2369d"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_4c6ab977fc6543f4810d52baaae2369d" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_4c6ab977fc6543f4810d52baaae2369d" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4c6ab977fc6543f4810d52baaae2369d").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_4c6ab977fc6543f4810d52baaae2369d").value);
#
#         const feedback =
#             document.getElementById("feedback_4c6ab977fc6543f4810d52baaae2369d");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (0)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué señal vale 1 para $n=0$ y 0 para $n\neq 0$?
#
# A. Escalón unitario
# B. Impulso unitario discreto
# C. Señal rampa
# D. Señal sinusoidal

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_71e6ef46ce1e429bba2bb83af959460f" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_71e6ef46ce1e429bba2bb83af959460f" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_71e6ef46ce1e429bba2bb83af959460f" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_71e6ef46ce1e429bba2bb83af959460f").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_71e6ef46ce1e429bba2bb83af959460f").value);
#
#         const feedback =
#             document.getElementById("feedback_71e6ef46ce1e429bba2bb83af959460f");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ### Propiedades básicas de los sistemas

# %%
create_true_false_exercise(
    statement="Un sistema sin memoria depende únicamente del valor actual de la entrada.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema causal puede depender de valores futuros de la entrada.",
    solution=False
)

create_true_false_exercise(
    statement="Un sistema estable produce una salida acotada para una entrada acotada.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema lineal cumple la propiedad de superposición.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema inversible permite recuperar la entrada a partir de la salida.",
    solution=True
)

create_true_false_exercise(
    statement="Todos los sistemas lineales son invariantes en el tiempo.",
    solution=False
)

create_true_false_exercise(
    statement="Un sistema puede ser causal e inestable al mismo tiempo.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema con memoria nunca puede ser causal.",
    solution=False
)

create_true_false_exercise(
    statement="Un sistema invariante en el tiempo responde igual aunque la entrada se desplace temporalmente.",
    solution=True
)

create_true_false_exercise(
    statement="Un sistema lineal siempre es físicamente realizable.",
    solution=False
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema sin memoria depende únicamente del valor actual de la entrada.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_97a994d4580245fba44954374ae5ae89" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_97a994d4580245fba44954374ae5ae89" value="false">
#             Falso
#         </label>
#
#         <button id="button_97a994d4580245fba44954374ae5ae89" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_97a994d4580245fba44954374ae5ae89" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_97a994d4580245fba44954374ae5ae89").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_97a994d4580245fba44954374ae5ae89");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_97a994d4580245fba44954374ae5ae89");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema causal puede depender de valores futuros de la entrada.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_bc85c996254f4258bac201063fe71893" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_bc85c996254f4258bac201063fe71893" value="false">
#             Falso
#         </label>
#
#         <button id="button_bc85c996254f4258bac201063fe71893" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_bc85c996254f4258bac201063fe71893" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_bc85c996254f4258bac201063fe71893").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_bc85c996254f4258bac201063fe71893");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_bc85c996254f4258bac201063fe71893");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema estable produce una salida acotada para una entrada acotada.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_9f47fcc7e00941aeb5fce11c4257c1e5" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_9f47fcc7e00941aeb5fce11c4257c1e5" value="false">
#             Falso
#         </label>
#
#         <button id="button_9f47fcc7e00941aeb5fce11c4257c1e5" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_9f47fcc7e00941aeb5fce11c4257c1e5" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_9f47fcc7e00941aeb5fce11c4257c1e5").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_9f47fcc7e00941aeb5fce11c4257c1e5");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_9f47fcc7e00941aeb5fce11c4257c1e5");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema lineal cumple la propiedad de superposición.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_7e5e1e76303f46bab6198d07ec0dff5c" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_7e5e1e76303f46bab6198d07ec0dff5c" value="false">
#             Falso
#         </label>
#
#         <button id="button_7e5e1e76303f46bab6198d07ec0dff5c" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_7e5e1e76303f46bab6198d07ec0dff5c" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_7e5e1e76303f46bab6198d07ec0dff5c").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_7e5e1e76303f46bab6198d07ec0dff5c");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_7e5e1e76303f46bab6198d07ec0dff5c");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>Un sistema inversible permite recuperar la entrada a partir de la salida.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_4a84aa0c2f03476f889a1f53513d314d" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_4a84aa0c2f03476f889a1f53513d314d" value="false">
#             Falso
#         </label>
#
#         <button id="button_4a84aa0c2f03476f889a1f53513d314d" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_4a84aa0c2f03476f889a1f53513d314d" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_4a84aa0c2f03476f889a1f53513d314d").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_4a84aa0c2f03476f889a1f53513d314d");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_4a84aa0c2f03476f889a1f53513d314d");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y[n]=x[n]+2$ y $x[0]=5$, ¿cuánto vale $y[0]$?

# %%
create_numeric_input_exercise(
    solution=7,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_80fccb4e48f7488e9bc506e8c51e8d7f"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_80fccb4e48f7488e9bc506e8c51e8d7f" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_80fccb4e48f7488e9bc506e8c51e8d7f" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_80fccb4e48f7488e9bc506e8c51e8d7f").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_80fccb4e48f7488e9bc506e8c51e8d7f").value);
#
#         const feedback =
#             document.getElementById("feedback_80fccb4e48f7488e9bc506e8c51e8d7f");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (7)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si un sistema cumple $y(t)=3x(t)$ y $x(t)=2$, ¿cuánto vale $y(t)$?

# %%
create_numeric_input_exercise(
    solution=6,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_fe59637798ef4143a3cf9812e2dc2572"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_fe59637798ef4143a3cf9812e2dc2572" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_fe59637798ef4143a3cf9812e2dc2572" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_fe59637798ef4143a3cf9812e2dc2572").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_fe59637798ef4143a3cf9812e2dc2572").value);
#
#         const feedback =
#             document.getElementById("feedback_fe59637798ef4143a3cf9812e2dc2572");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (6)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué propiedad debe cumplir un sistema lineal?
#
# A. Periodicidad
# B. Superposición
# C. Energía infinita
# D. Memoria

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_2d8204655be34e06a9d5ebefad4f759e" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_2d8204655be34e06a9d5ebefad4f759e" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_2d8204655be34e06a9d5ebefad4f759e" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_2d8204655be34e06a9d5ebefad4f759e").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_2d8204655be34e06a9d5ebefad4f759e").value);
#
#         const feedback =
#             document.getElementById("feedback_2d8204655be34e06a9d5ebefad4f759e");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ### Interconexión de sistemas

# %%
create_true_false_exercise(
    statement="En una conexión en serie, la salida de un sistema es la entrada del siguiente.",
    solution=True
)

create_true_false_exercise(
    statement="En una conexión en paralelo, todos los sistemas reciben la misma entrada.",
    solution=True
)

create_true_false_exercise(
    statement="En una conexión en paralelo, las salidas de los sistemas se suman.",
    solution=True
)

create_true_false_exercise(
    statement="La realimentación utiliza parte de la salida del sistema.",
    solution=True
)

create_true_false_exercise(
    statement="En una interconexión en paralelo, las salidas de los sistemas se suman.",
    solution=True
)

create_true_false_exercise(
    statement="La realimentación consiste en conectar sistemas únicamente en serie.",
    solution=False
)

create_true_false_exercise(
    statement="En una conexión en cascada, la salida de un sistema alimenta al siguiente.",
    solution=True
)

create_true_false_exercise(
    statement="Dos sistemas lineales en cascada producen otro sistema lineal.",
    solution=True
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>En una conexión en serie, la salida de un sistema es la entrada del siguiente.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_d19e546e9aae42fbbefc3f02356b530d" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_d19e546e9aae42fbbefc3f02356b530d" value="false">
#             Falso
#         </label>
#
#         <button id="button_d19e546e9aae42fbbefc3f02356b530d" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_d19e546e9aae42fbbefc3f02356b530d" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_d19e546e9aae42fbbefc3f02356b530d").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_d19e546e9aae42fbbefc3f02356b530d");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_d19e546e9aae42fbbefc3f02356b530d");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>En una conexión en paralelo, todos los sistemas reciben la misma entrada.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_8f989255610e415a95d1dac0bda04a6c" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_8f989255610e415a95d1dac0bda04a6c" value="false">
#             Falso
#         </label>
#
#         <button id="button_8f989255610e415a95d1dac0bda04a6c" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_8f989255610e415a95d1dac0bda04a6c" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_8f989255610e415a95d1dac0bda04a6c").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_8f989255610e415a95d1dac0bda04a6c");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_8f989255610e415a95d1dac0bda04a6c");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>En una conexión en paralelo, las salidas de los sistemas se suman.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_b551a784739c4cdaaebcba60dc8594d7" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_b551a784739c4cdaaebcba60dc8594d7" value="false">
#             Falso
#         </label>
#
#         <button id="button_b551a784739c4cdaaebcba60dc8594d7" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_b551a784739c4cdaaebcba60dc8594d7" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_b551a784739c4cdaaebcba60dc8594d7").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_b551a784739c4cdaaebcba60dc8594d7");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_b551a784739c4cdaaebcba60dc8594d7");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>La realimentación utiliza parte de la salida del sistema.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_e1dd9065ff5b489a9468874b4b3396c9" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_e1dd9065ff5b489a9468874b4b3396c9" value="false">
#             Falso
#         </label>
#
#         <button id="button_e1dd9065ff5b489a9468874b4b3396c9" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_e1dd9065ff5b489a9468874b4b3396c9" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_e1dd9065ff5b489a9468874b4b3396c9").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_e1dd9065ff5b489a9468874b4b3396c9");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_e1dd9065ff5b489a9468874b4b3396c9");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "true") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:12px;
#         margin:10px 0;
#         background:#f8f9fa;
#         display:flex;
#         align-items:center;
#         gap:15px;
#         flex-wrap:wrap;
#     ">
#
#         <span><strong>La realimentación consiste únicamente en conectar sistemas en serie.</strong></span>
#
#         <label>
#             <input type="radio" name="radio_60d5ce13a7fd4e60967f8fdb89545901" value="true">
#             Verdadero
#         </label>
#
#         <label>
#             <input type="radio" name="radio_60d5ce13a7fd4e60967f8fdb89545901" value="false">
#             Falso
#         </label>
#
#         <button id="button_60d5ce13a7fd4e60967f8fdb89545901" style="
#             padding:4px 10px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <span id="feedback_60d5ce13a7fd4e60967f8fdb89545901" style="
#             font-weight:bold;
#         "></span>
#
#     </div>
#
#     <script>
#     document.getElementById("button_60d5ce13a7fd4e60967f8fdb89545901").onclick = function() {
#
#         const radios =
#             document.getElementsByName("radio_60d5ce13a7fd4e60967f8fdb89545901");
#
#         let selected = null;
#
#         for (const radio of radios) {
#             if (radio.checked) {
#                 selected = radio.value;
#             }
#         }
#
#         const feedback =
#             document.getElementById("feedback_60d5ce13a7fd4e60967f8fdb89545901");
#
#         if (selected === null) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === "false") {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# Si en paralelo se suman dos señales y sus salidas son 3 y 5, ¿cuál es la salida total?

# %%
create_numeric_input_exercise(
    solution=8,
    tolerance=0
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <p><strong>Ingresa tu respuesta:</strong></p>
#
#         <input
#             type="number"
#             id="input_55632703e0fc459e838a59db38a4cae3"
#             step="any"
#             placeholder="Tu respuesta aquí"
#             style="
#                 padding:6px;
#                 border-radius:6px;
#                 width:150px;
#             "
#         >
#
#         <button id="button_55632703e0fc459e838a59db38a4cae3" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_55632703e0fc459e838a59db38a4cae3" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_55632703e0fc459e838a59db38a4cae3").onclick = function() {
#
#         const value =
#             parseFloat(document.getElementById("input_55632703e0fc459e838a59db38a4cae3").value);
#
#         const feedback =
#             document.getElementById("feedback_55632703e0fc459e838a59db38a4cae3");
#
#         if (isNaN(value)) {
#             feedback.innerHTML = "Por favor, ingresa un número.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (Math.abs(value - (8)) <= 0) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>

# %% [markdown]
# ¿Qué tipo de conexión usa la salida de un sistema como entrada del siguiente?
#
# A. Paralelo
# B. Cascada
# C. Realimentación
# D. Muestreo

# %%
create_answer_selector(
    num_options=4,
    solution=2,
    mode="alphabetic"
)
# Out:
#     <div style="
#         border:1px solid #ccc;
#         border-radius:10px;
#         padding:15px;
#         margin:10px 0;
#         background:#f8f9fa;
#     ">
#
#         <select id="select_851795971c4148dea8ad780aa6363628" style="
#             padding:6px;
#             border-radius:6px;
#         ">
#             <option value="">-- Elige una opción --</option><option value="1">A</option><option value="2">B</option><option value="3">C</option><option value="4">D</option>
#         </select>
#
#         <button id="button_851795971c4148dea8ad780aa6363628" style="
#             margin-left:10px;
#             padding:6px 12px;
#             border-radius:6px;
#             cursor:pointer;
#         ">
#             Evaluar
#         </button>
#
#         <p id="feedback_851795971c4148dea8ad780aa6363628" style="
#             margin-top:10px;
#             font-weight:bold;
#         "></p>
#
#     </div>
#
#     <script>
#     document.getElementById("button_851795971c4148dea8ad780aa6363628").onclick = function() {
#
#         const selected =
#             Number(document.getElementById("select_851795971c4148dea8ad780aa6363628").value);
#
#         const feedback =
#             document.getElementById("feedback_851795971c4148dea8ad780aa6363628");
#
#         if (!selected) {
#             feedback.innerHTML = "Selecciona una opción.";
#             feedback.style.color = "orange";
#             return;
#         }
#
#         if (selected === 2) {
#             feedback.innerHTML = "¡Correcto!";
#             feedback.style.color = "green";
#         } else {
#             feedback.innerHTML = "¡Incorrecto! Inténtalo de nuevo.";
#             feedback.style.color = "red";
#         }
#     };
#     </script>
